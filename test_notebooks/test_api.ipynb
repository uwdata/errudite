# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

def import_sys():
    import sys
    sys.path.append('..')
    sys.path.append('../..')
import_sys()

import errudite
import yaml
import traceback
from errudite.server.api import API

config_file = "../config.yml"

with open(config_file) as f:
    configs = yaml.load(f)
print (configs)
API_CONSTRUCTOR =  API.by_name(configs["task"])
try:
    api = API_CONSTRUCTOR(
            cache_path=configs["cache_path"],
            model_metas=configs["model_metas"],
            attr_file_name=configs["attr_file_name"],
            group_file_name=configs["group_file_name"],
            rewrite_file_name=configs["rewrite_file_name"]
        )
except:
    traceback.print_exc()
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# WARNING:errudite.utils.file_utils:Local path not yet exist, but still parsed: /Users/tongshuangwu/sourcetree/errudite-uwdata/test_notebooks/caches/vocab.pkl
# WARNING:errudite.processor.spacy_annotator:(2, 'No such file or directory')
# INFO:pytorch_pretrained_bert.modeling:Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# /Users/tongshuangwu/sourcetree/errudite-uwdata/venv/lib/python3.6/site-packages/sklearn/utils/linear_assignment_.py:21: DeprecationWarning: The linear_assignment_ module is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# INFO:errudite.server.api:qa: Finding cache folder and loading instances...
# INFO:errudite.utils.file_utils:Errudite cache folder selected: /Users/tongshuangwu/datasets/caches/error_analysis/squad-100/
# ...

# %%
from errudite.targets.label import Label
Label.resolve_default_perform_name()
# Out:
# 'f1'

# %%
api.sample_instances(
    selected_predictor=None, 
    cmd=None,
    sample_method='worst', 
    sample_rewrite=None, 
    sample_size=10,
    test_size=10570,
    show_filtered_arr=False, 
    show_filtered_err_overlap=False,
    show_filtered_group=False,
    show_filtered_rewrite=False,
    qids_input=[])
# Out:
# WARNING:errudite.utils.registrable:Register is_digit as PrimFunc: Overwritting name already in use for is_digit.
# WARNING:errudite.utils.registrable:Register digitize as PrimFunc: Overwritting name already in use for digitize.
# WARNING:errudite.utils.registrable:Register truncate as PrimFunc: Overwritting name already in use for truncate.
# WARNING:errudite.utils.registrable:Register abs_num as PrimFunc: Overwritting name already in use for abs_num.
# INFO:errudite.build_blocks.wrapper:Parsed: True
# INFO:errudite.builts.group:Created group: temp
# {'sample_cache_idx': 0,
#  'sampled_keys': [{'qid': '56d6017d1c85041400946ec2',
#    'vid': 0,
#    'rid': 'unrewritten',
#    'aid': 0,
#    'cid': 1},
#   {'qid': '56bf10f43aeaaa14008c94fd',
#    'vid': 0,
#    'rid': 'unrewritten',
#    'aid': 0,
#    'cid': 0},
#   {'qid': '56d98a59dc89441400fdb52e',
#    'vid': 0,
#    'rid': 'unrewritten',
#    'aid': 0,
#    'cid': 1},
#   {'qid': '56d9895ddc89441400fdb510',
#    'vid': 0,
# ...
